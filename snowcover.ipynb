# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
meteofrance=pd.read_csv("C:/Users/sarahv/Documents/data_monthly_FR_METEOFRANCE/data_monthly_FR_METEOFRANCE.csv")

# %%
time=[datetime.datetime(meteofrance["year"].values[i], meteofrance["month"].values[i],15) for i in range(len(meteofrance["year"].values))]

# %%
meteofrance["time"] = time

# %%
set(meteofrance["Name"].values)
# Out:
# {'Abries_rm',
#  'Agnieres_en_devoluy',
#  'Aigleton_nivose',
#  'Aiguilles_rouges_nivose',
#  'Aiguines',
#  'Aiguines_sapc',
#  'Albiez',
#  'Allant_nivose',
#  'Allemond',
#  'Allos',
#  'Alpe_d_huez',
#  'Ancelle',
#  'Antibes_garoupe',
#  'Areches',
#  'Arvieux_la_chalp',
#  'Auris',
#  'Auris_en_oisans',
#  'Auron',
#  'Aussois',
#  'Aussois_clim',
#  'Autrans',
#  'Autrans_nivo',
#  'Avoriaz',
#  'Avrieux',
#  'Ayze',
#  'Beaufort_sur_doron',
#  'Bellecote_nivose',
#  'Bernex',
#  'Bessans',
#  'Bessans_clim',
#  'Besse',
#  'Beuil_obs',
#  'Boege',
#  'Bonneval_nivose',
#  'Bonneval_sur_arc',
#  'Bourg_d_oisans',
#  'Bourg_st_maurice',
#  'Bouvante',
#  'Bozel',
#  'Briancon',
#  'Cannes',
#  'Cap_ferrat',
#  'Carpentras',
#  'Ceillac',
#  'Ceillac_nivo',
#  'Cervieres',
#  'Chambery_aix',
#  'Chamonix',
#  'Chamonix_obs',
#  'Champcella',
#  'Chamrousse_arselle',
#  'Chamrousse_niverolles',
#  'Chapelle_en_valgaudemar',
#  'Chapelle_en_ver',
#  'Chateau_ville_vieille',
# ...

# %%
cdp = meteofrance[meteofrance["Name"]=="Col_de_porte"]

# %%
cdp
# Out:
#                Name  year  month  HN  HS  HS_gapfill  HS_gapfill_frac  \
# 24888  Col_de_porte  1960      1 NaN NaN         NaN              NaN
# 24889  Col_de_porte  1960      2 NaN NaN         NaN              NaN
# 24890  Col_de_porte  1960      3 NaN NaN         NaN              NaN
# 24891  Col_de_porte  1960      4 NaN NaN         NaN              NaN
# 24892  Col_de_porte  1960      5 NaN NaN         NaN              NaN
# ...             ...   ...    ...  ..  ..         ...              ...
# 25615  Col_de_porte  2020      8 NaN NaN         NaN              NaN
# 25616  Col_de_porte  2020      9 NaN NaN         NaN              NaN
# 25617  Col_de_porte  2020     10 NaN NaN         NaN              NaN
# 25618  Col_de_porte  2020     11 NaN NaN         NaN              NaN
# 25619  Col_de_porte  2020     12 NaN NaN         NaN              NaN
#
#             time
# 24888 1960-01-15
# 24889 1960-02-15
# 24890 1960-03-15
# 24891 1960-04-15
# 24892 1960-05-15
# ...

# %%
plt.plot(cdp["time"].values, cdp["HN"].values)
plt.xlabel("Time")
plt.ylabel("Depth of snowfall [cm]")
# Out:
# Text(0, 0.5, 'Depth of snowfall [cm]')

# %%
plt.plot(cdp["time"].values, cdp["HS"].values)
plt.xlabel("Time")
plt.ylabel("Snow depth [cm]")
# Out:
# Text(0, 0.5, 'Snow depth [cm]')
